# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=650b800a6f4310e332dc5228b1492c28

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdescription = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdescription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | burla
# Processing Record 2 of Set 15 | arraial do cabo
# Processing Record 3 of Set 15 | dunedin
# Processing Record 4 of Set 15 | mezen
# Processing Record 5 of Set 15 | kommunar
# Processing Record 6 of Set 15 | busselton
# Processing Record 7 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 15 | kahului
# Processing Record 9 of Set 15 | jiayuguan
# Processing Record 10 of Set 15 | inirida
# Processing Record 11 of Set 15 | kodiak
# Processing Record 12 of Set 15 | conceicao do araguaia
# Processing Record 13 of Set 15 | tutoia
# Processing Record 14 of Set 15 | chokurdakh
# Processing Record 15 of Set 15 | port alfred
# Processing Record 16 of Set 15 | namibe
# Processing Record 17 of Set 15 | sur
# Processing Record 18 of Set 15 | jamestown
# Processing Record 19 of Set 15 | charlestown
# Processing Record 20 of Set 15 | rikitea
# Processing Record 21 of Set 15 | butaritari
# Processing Record 22 of Set 15 | kyren
# Processing Record 23 of Set 15 | tomatlan
# Processing Record 24 of Set 15 | ponta do sol
# Processing Record 25 of Set 15 | mataura
# Processing Record 26 of Set 15 | thompson
# Processing Record 27 of Set 15 | shasta lake
# Processing Record 28 of Set 15 | pevek
# Processing Record 29 of Set 15 | bol
# Processing Record 30 of Set 15 | lagoa
# Processing Record 31 of Set 15 | tuktoyaktuk
# Processing Record 32 of Set 15 | chuy
# Processing Record 33 of Set 15 | cape town
# Processing Record 34 of Set 15 | kapaa
# Processing Record 35 of Set 15 | atuona
# Processing Record 36 of Set 15 | puerto ayora
# Processing Record 37 of Set 15 | ruiz
# Processing Record 38 of Set 15 | geraldton
# Processing Record 39 of Set 15 | phalodi
# Processing Record 40 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 15 | mokhsogollokh
# Processing Record 42 of Set 15 | nikolskoye
# Processing Record 43 of Set 15 | vila velha
# Processing Record 44 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 15 | souillac
# Processing Record 47 of Set 15 | ushuaia
# Processing Record 48 of Set 15 | mahebourg
# Processing Record 49 of Set 15 | bambous virieux
# Processing Record 50 of Set 15 | vaini
# Processing Record 1 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 16 | pundaguitan
# Processing Record 3 of Set 16 | pontal do parana
# Processing Record 4 of Set 16 | tual
# Processing Record 5 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 16 | fiumicino
# Processing Record 7 of Set 16 | bethel
# Processing Record 8 of Set 16 | harper
# Processing Record 9 of Set 16 | port elizabeth
# Processing Record 10 of Set 16 | davila
# Processing Record 11 of Set 16 | faanui
# Processing Record 12 of Set 16 | esmeralda
# Processing Record 13 of Set 16 | punta arenas
# Processing Record 14 of Set 16 | lebu
# Processing Record 15 of Set 16 | taoudenni
# Processing Record 16 of Set 16 | codrington
# Processing Record 17 of Set 16 | mar del plata
# Processing Record 18 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 16 | boa vista
# Processing Record 20 of Set 16 | tiksi
# Processing Record 21 of Set 16 | peniche
# Processing Record 22 of Set 16 | airai
# Processing Record 23 of Set 16 | korla
# Processing Record 24 of Set 16 | cabo san lucas
# Processing Record 25 of Set 16 | barrow
# Processing Record 26 of Set 16 | touros
# Processing Record 27 of Set 16 | sfantu gheorghe
# Processing Record 28 of Set 16 | yellowknife
# Processing Record 29 of Set 16 | hithadhoo
# Processing Record 30 of Set 16 | hasaki
# Processing Record 31 of Set 16 | acapulco
# Processing Record 32 of Set 16 | pangoa
# Processing Record 33 of Set 16 | hermanus
# Processing Record 34 of Set 16 | akyab
# Processing Record 35 of Set 16 | pitimbu
# Processing Record 36 of Set 16 | pleasanton
# Processing Record 37 of Set 16 | esperance
# Processing Record 38 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 16 | new norfolk
# Processing Record 40 of Set 16 | half moon bay
# Processing Record 41 of Set 16 | nicoya
# Processing Record 42 of Set 16 | balkanabat
# Processing Record 43 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 16 | patos
# Processing Record 45 of Set 16 | arlit
# Processing Record 46 of Set 16 | golden
# Processing Record 47 of Set 16 | norman wells
# Processing Record 48 of Set 16 | cockburn town
# Processing Record 49 of Set 16 | grand gaube
# Processing Record 50 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 17 | lompoc
# Processing Record 2 of Set 17 | north bend
# Processing Record 3 of Set 17 | aljezur
# Processing Record 4 of Set 17 | castro
# Processing Record 5 of Set 17 | dingle
# Processing Record 6 of Set 17 | tezu
# Processing Record 7 of Set 17 | hasilpur
# Processing Record 8 of Set 17 | sompeta
# Processing Record 9 of Set 17 | oriximina
# Processing Record 10 of Set 17 | comrie
# Processing Record 11 of Set 17 | pisco
# Processing Record 12 of Set 17 | bredasdorp
# Processing Record 13 of Set 17 | raga
# Processing Record 14 of Set 17 | hilo
# Processing Record 15 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 17 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 17 | buala
# Processing Record 19 of Set 17 | west bay
# Processing Record 20 of Set 17 | aklavik
# Processing Record 21 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 17 | sao filipe
# Processing Record 23 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 17 | vestmannaeyjar
# Processing Record 25 of Set 17 | talnakh
# Processing Record 26 of Set 17 | makakilo city
# Processing Record 27 of Set 17 | aloleng
# Processing Record 28 of Set 17 | isangel
# Processing Record 29 of Set 17 | cidreira
# Processing Record 30 of Set 17 | nelson bay
# Processing Record 31 of Set 17 | linjiang
# Processing Record 32 of Set 17 | talara
# Processing Record 33 of Set 17 | ribeira grande
# Processing Record 34 of Set 17 | ilulissat
# Processing Record 35 of Set 17 | santiago del estero
# Processing Record 36 of Set 17 | gachala
# Processing Record 37 of Set 17 | san cristobal
# Processing Record 38 of Set 17 | port hedland
# Processing Record 39 of Set 17 | ippy
# Processing Record 40 of Set 17 | bengkulu
# Processing Record 41 of Set 17 | acajutla
# Processing Record 42 of Set 17 | verkhnevilyuysk
# Processing Record 43 of Set 17 | vetlanda
# Processing Record 44 of Set 17 | tame
# Processing Record 45 of Set 17 | bluff
# Processing Record 46 of Set 17 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 17 | bukachacha
# Processing Record 48 of Set 17 | upernavik
# Processing Record 49 of Set 17 | victoria
# Processing Record 50 of Set 17 | pabna
# Processing Record 1 of Set 18 | kindu
# Processing Record 2 of Set 18 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 18 | hofn
# Processing Record 4 of Set 18 | beringovskiy
# Processing Record 5 of Set 18 | camana
# Processing Record 6 of Set 18 | kingman
# Processing Record 7 of Set 18 | mitsamiouli
# Processing Record 8 of Set 18 | tasiilaq
# Processing Record 9 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 18 | nzerekore
# Processing Record 11 of Set 18 | naze
# Processing Record 12 of Set 18 | lorengau
# Processing Record 13 of Set 18 | torbay
# Processing Record 14 of Set 18 | adrar
# Processing Record 15 of Set 18 | bijie
# Processing Record 16 of Set 18 | marzuq
# Processing Record 17 of Set 18 | saint-philippe
# Processing Record 18 of Set 18 | albany
# Processing Record 19 of Set 18 | padang
# Processing Record 20 of Set 18 | atar
# Processing Record 21 of Set 18 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 18 | opuwo
# Processing Record 23 of Set 18 | lincoln
# Processing Record 24 of Set 18 | luderitz
# Processing Record 25 of Set 18 | moengo
# Processing Record 26 of Set 18 | saskylakh
# Processing Record 27 of Set 18 | cruden bay
# City not found. Skipping...
# Processing Record 28 of Set 18 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 18 | iqaluit
# Processing Record 30 of Set 18 | palmer
# Processing Record 31 of Set 18 | haines junction
# Processing Record 32 of Set 18 | fort walton beach
# Processing Record 33 of Set 18 | havoysund
# Processing Record 34 of Set 18 | la ronge
# Processing Record 35 of Set 18 | kodinsk
# Processing Record 36 of Set 18 | behbahan
# Processing Record 37 of Set 18 | viedma
# Processing Record 38 of Set 18 | japura
# Processing Record 39 of Set 18 | saldanha
# Processing Record 40 of Set 18 | te anau
# Processing Record 41 of Set 18 | clyde river
# Processing Record 42 of Set 18 | ploemeur
# Processing Record 43 of Set 18 | kalmunai
# Processing Record 44 of Set 18 | hobart
# Processing Record 45 of Set 18 | carnarvon
# Processing Record 46 of Set 18 | provideniya
# Processing Record 47 of Set 18 | danjiangkou
# Processing Record 48 of Set 18 | westport
# Processing Record 49 of Set 18 | george town
# Processing Record 50 of Set 18 | south yuba city
# Processing Record 1 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 19 | east london
# Processing Record 3 of Set 19 | altay
# Processing Record 4 of Set 19 | lipin bor
# Processing Record 5 of Set 19 | asau
# Processing Record 6 of Set 19 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 19 | bumba
# Processing Record 8 of Set 19 | golspie
# Processing Record 9 of Set 19 | la quinta
# Processing Record 10 of Set 19 | beloeil
# Processing Record 11 of Set 19 | dikson
# Processing Record 12 of Set 19 | salalah
# Processing Record 13 of Set 19 | lavrentiya
# Processing Record 14 of Set 19 | sokoni
# Processing Record 15 of Set 19 | tooele
# Processing Record 16 of Set 19 | caravelas
# Processing Record 17 of Set 19 | mikuni
# Processing Record 18 of Set 19 | katsuura
# Processing Record 19 of Set 19 | salinopolis
# Processing Record 20 of Set 19 | sidi bu zayd
# City not found. Skipping...
# Processing Record 21 of Set 19 | maniitsoq
# Processing Record 22 of Set 19 | sobolevo
# Processing Record 23 of Set 19 | dingtao
# Processing Record 24 of Set 19 | miri
# Processing Record 25 of Set 19 | ketchikan
# Processing Record 26 of Set 19 | shelburne
# Processing Record 27 of Set 19 | khatanga
# Processing Record 28 of Set 19 | palaikastron
# Processing Record 29 of Set 19 | uvinza
# Processing Record 30 of Set 19 | mujiayingzi
# Processing Record 31 of Set 19 | moerai
# Processing Record 32 of Set 19 | dicabisagan
# Processing Record 33 of Set 19 | visby
# Processing Record 34 of Set 19 | luangwa
# Processing Record 35 of Set 19 | walvis bay
# Processing Record 36 of Set 19 | burica
# City not found. Skipping...
# Processing Record 37 of Set 19 | upata
# Processing Record 38 of Set 19 | portland
# Processing Record 39 of Set 19 | christchurch
# Processing Record 40 of Set 19 | okhotsk
# Processing Record 41 of Set 19 | qaanaaq
# Processing Record 42 of Set 19 | megion
# Processing Record 43 of Set 19 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 19 | fortuna
# Processing Record 45 of Set 19 | tritenii de jos
# Processing Record 46 of Set 19 | sawakin
# Processing Record 47 of Set 19 | khasan
# Processing Record 48 of Set 19 | yar-sale
# Processing Record 49 of Set 19 | port moresby
# Processing Record 50 of Set 19 | graham
# Processing Record 1 of Set 20 | itacarambi
# Processing Record 2 of Set 20 | guerrero negro
# Processing Record 3 of Set 20 | fort nelson
# Processing Record 4 of Set 20 | pascagoula
# Processing Record 5 of Set 20 | saint george
# Processing Record 6 of Set 20 | qurbus
# Processing Record 7 of Set 20 | trairi
# Processing Record 8 of Set 20 | gotsu
# Processing Record 9 of Set 20 | hamilton
# Processing Record 10 of Set 20 | flinders
# Processing Record 11 of Set 20 | avarua
# Processing Record 12 of Set 20 | nanortalik
# Processing Record 13 of Set 20 | tambopata
# Processing Record 14 of Set 20 | shu
# Processing Record 15 of Set 20 | encinitas
# Processing Record 16 of Set 20 | saint-augustin
# Processing Record 17 of Set 20 | auki
# Processing Record 18 of Set 20 | hovd
# Processing Record 19 of Set 20 | sakakah
# Processing Record 20 of Set 20 | qianan
# Processing Record 21 of Set 20 | ingham
# Processing Record 22 of Set 20 | creston
# Processing Record 23 of Set 20 | kaitangata
# Processing Record 24 of Set 20 | machiques
# Processing Record 25 of Set 20 | mayo
# Processing Record 26 of Set 20 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 27 of Set 20 | vila
# Processing Record 28 of Set 20 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 20 | tuatapere
# Processing Record 30 of Set 20 | thaba nchu
# Processing Record 31 of Set 20 | durban
# Processing Record 32 of Set 20 | talladega
# Processing Record 33 of Set 20 | vestmanna
# Processing Record 34 of Set 20 | husavik
# Processing Record 35 of Set 20 | san francisco
# Processing Record 36 of Set 20 | itarema
# Processing Record 37 of Set 20 | longyearbyen
# Processing Record 38 of Set 20 | olavarria
# Processing Record 39 of Set 20 | grindavik
# Processing Record 40 of Set 20 | elwood
# Processing Record 41 of Set 20 | severo-kurilsk
# Processing Record 42 of Set 20 | vaitape
# Processing Record 43 of Set 20 | coihaique
# Processing Record 44 of Set 20 | dembi dolo
# Processing Record 45 of Set 20 | port lavaca
# Processing Record 46 of Set 20 | yenagoa
# Processing Record 47 of Set 20 | coquimbo
# Processing Record 48 of Set 20 | vao
# Processing Record 49 of Set 20 | nuevitas
# Processing Record 50 of Set 20 | ilhabela
# Processing Record 1 of Set 21 | rorvik
# Processing Record 2 of Set 21 | dong hoi
# Processing Record 3 of Set 21 | inuvik
# Processing Record 4 of Set 21 | vardo
# Processing Record 5 of Set 21 | goycay
# City not found. Skipping...
# Processing Record 6 of Set 21 | antioch
# Processing Record 7 of Set 21 | sitka
# Processing Record 8 of Set 21 | rajnagar
# Processing Record 9 of Set 21 | santiago
# Processing Record 10 of Set 21 | safaga
# Processing Record 11 of Set 21 | ossora
# Processing Record 12 of Set 21 | sao felix do xingu
# Processing Record 13 of Set 21 | umm kaddadah
# Processing Record 14 of Set 21 | nadvoitsy
# Processing Record 15 of Set 21 | bojnurd
# Processing Record 16 of Set 21 | saint-jacques
# Processing Record 17 of Set 21 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 21 | salvador
# Processing Record 19 of Set 21 | mount gambier
# Processing Record 20 of Set 21 | erenhot
# Processing Record 21 of Set 21 | sinnamary
# Processing Record 22 of Set 21 | qui nhon
# Processing Record 23 of Set 21 | shaoxing
# Processing Record 24 of Set 21 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 21 | lages
# Processing Record 26 of Set 21 | tautira
# Processing Record 27 of Set 21 | kadoma
# Processing Record 28 of Set 21 | puerto colombia
# Processing Record 29 of Set 21 | gore
# Processing Record 30 of Set 21 | felidhoo
# City not found. Skipping...
# Processing Record 31 of Set 21 | anadyr
# Processing Record 32 of Set 21 | nyakabindi
# Processing Record 33 of Set 21 | kloulklubed
# Processing Record 34 of Set 21 | berlevag
# Processing Record 35 of Set 21 | bestobe
# Processing Record 36 of Set 21 | leningradskiy
# Processing Record 37 of Set 21 | tecoanapa
# Processing Record 38 of Set 21 | saint-georges
# Processing Record 39 of Set 21 | zhigansk
# Processing Record 40 of Set 21 | mana
# Processing Record 41 of Set 21 | thunder bay
# Processing Record 42 of Set 21 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 21 | bathsheba
# Processing Record 45 of Set 21 | manzhouli
# Processing Record 46 of Set 21 | itaperucu
# Processing Record 47 of Set 21 | pacific grove
# Processing Record 48 of Set 21 | morondava
# Processing Record 49 of Set 21 | krasnyy chikoy
# Processing Record 50 of Set 21 | belle fourche
# Processing Record 1 of Set 22 | asyut
# Processing Record 2 of Set 22 | jaciara
# Processing Record 3 of Set 22 | khash
# Processing Record 4 of Set 22 | bubaque
# Processing Record 5 of Set 22 | madisonville
# Processing Record 6 of Set 22 | paris
# Processing Record 7 of Set 22 | quatre cocos
# Processing Record 8 of Set 22 | merritt
# Processing Record 9 of Set 22 | boguchany
# Processing Record 10 of Set 22 | biltine
# Processing Record 11 of Set 22 | evensk
# Processing Record 12 of Set 22 | atbasar
# Processing Record 13 of Set 22 | nelidovo
# Processing Record 14 of Set 22 | umm lajj
# Processing Record 15 of Set 22 | ialibu
# Processing Record 16 of Set 22 | litovko
# Processing Record 17 of Set 22 | omsukchan
# Processing Record 18 of Set 22 | dhidhdhoo
# Processing Record 19 of Set 22 | dakar
# Processing Record 20 of Set 22 | new cumnock
# Processing Record 21 of Set 22 | nouadhibou
# Processing Record 22 of Set 22 | yablonovo
# Processing Record 23 of Set 22 | rivadavia
# Processing Record 24 of Set 22 | jamsa
# Processing Record 25 of Set 22 | suoyarvi
# Processing Record 26 of Set 22 | kerchevskiy
# Processing Record 27 of Set 22 | constitucion
# Processing Record 28 of Set 22 | luganville
# Processing Record 29 of Set 22 | turukhansk
# Processing Record 30 of Set 22 | inongo
# Processing Record 31 of Set 22 | aripuana
# Processing Record 32 of Set 22 | san carlos de bariloche
# Processing Record 33 of Set 22 | alyangula
# Processing Record 34 of Set 22 | warwick
# Processing Record 35 of Set 22 | sistranda
# Processing Record 36 of Set 22 | pangnirtung
# Processing Record 37 of Set 22 | butembo
# Processing Record 38 of Set 22 | erzin
# Processing Record 39 of Set 22 | kasangulu
# Processing Record 40 of Set 22 | labuhan
# Processing Record 41 of Set 22 | faya
# Processing Record 42 of Set 22 | taguatinga
# Processing Record 43 of Set 22 | rocha
# Processing Record 44 of Set 22 | ancud
# Processing Record 45 of Set 22 | dekar
# Processing Record 46 of Set 22 | along
# Processing Record 47 of Set 22 | bemidji
# Processing Record 48 of Set 22 | kenora
# Processing Record 49 of Set 22 | buchanan
# Processing Record 50 of Set 22 | manresa
# Processing Record 1 of Set 23 | meulaboh
# Processing Record 2 of Set 23 | laguna
# Processing Record 3 of Set 23 | rio gallegos
# Processing Record 4 of Set 23 | voyvozh
# Processing Record 5 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 23 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 23 | tukrah
# Processing Record 8 of Set 23 | lanzhou
# Processing Record 9 of Set 23 | arrifes
# Processing Record 10 of Set 23 | port hardy
# Processing Record 11 of Set 23 | myitkyina
# Processing Record 12 of Set 23 | svetlogorsk
# Processing Record 13 of Set 23 | oranjemund
# Processing Record 14 of Set 23 | georgetown
# Processing Record 15 of Set 23 | mnogovershinnyy
# Processing Record 16 of Set 23 | torrijos
# Processing Record 17 of Set 23 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 23 | jacareacanga
# Processing Record 19 of Set 23 | lalomanu
# City not found. Skipping...
# Processing Record 20 of Set 23 | palu
# Processing Record 21 of Set 23 | dudinka
# Processing Record 22 of Set 23 | boshnyakovo
# Processing Record 23 of Set 23 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 23 | deputatskiy
# Processing Record 25 of Set 23 | kavieng
# Processing Record 26 of Set 23 | tazovskiy
# Processing Record 27 of Set 23 | campbell river
# Processing Record 28 of Set 23 | kieta
# Processing Record 29 of Set 23 | chicama
# Processing Record 30 of Set 23 | rovaniemi
# Processing Record 31 of Set 23 | samarai
# Processing Record 32 of Set 23 | itagiba
# Processing Record 33 of Set 23 | atasu
# Processing Record 34 of Set 23 | seoul
# Processing Record 35 of Set 23 | klaksvik
# Processing Record 36 of Set 23 | avera
# Processing Record 37 of Set 23 | miranda
# Processing Record 38 of Set 23 | sao joao da barra
# Processing Record 39 of Set 23 | acarau
# Processing Record 40 of Set 23 | necochea
# Processing Record 41 of Set 23 | port blair
# Processing Record 42 of Set 23 | nouakchott
# Processing Record 43 of Set 23 | mirabad
# Processing Record 44 of Set 23 | manaus
# Processing Record 45 of Set 23 | tessalit
# Processing Record 46 of Set 23 | yelizovo
# Processing Record 47 of Set 23 | gat
# Processing Record 48 of Set 23 | byron bay
# Processing Record 49 of Set 23 | mayumba
# Processing Record 50 of Set 23 | filadelfia
# Processing Record 1 of Set 24 | amsterdam
# Processing Record 2 of Set 24 | miquelon
# Processing Record 3 of Set 24 | bilibino
# Processing Record 4 of Set 24 | mandalgovi
# Processing Record 5 of Set 24 | makushino
# Processing Record 6 of Set 24 | kulhudhuffushi
# Processing Record 7 of Set 24 | meadow lake
# Processing Record 8 of Set 24 | coihueco
# Processing Record 9 of Set 24 | ruteng
# Processing Record 10 of Set 24 | athabasca
# Processing Record 11 of Set 24 | priego de cordoba
# Processing Record 12 of Set 24 | tyrma
# Processing Record 13 of Set 24 | moron
# Processing Record 14 of Set 24 | yerbogachen
# Processing Record 15 of Set 24 | puerto escondido
# Processing Record 16 of Set 24 | goderich
# Processing Record 17 of Set 24 | rancho palos verdes
# Processing Record 18 of Set 24 | mount isa
# Processing Record 19 of Set 24 | pemex
# Processing Record 20 of Set 24 | cienaga de flores
# City not found. Skipping...
# Processing Record 21 of Set 24 | qaqortoq
# Processing Record 22 of Set 24 | oistins
# Processing Record 23 of Set 24 | nata
# Processing Record 24 of Set 24 | kathu
# Processing Record 25 of Set 24 | abu kamal
# Processing Record 26 of Set 24 | kudahuvadhoo
# Processing Record 27 of Set 24 | koungou
# Processing Record 28 of Set 24 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 24 | kasongo
# Processing Record 30 of Set 24 | suntar
# Processing Record 31 of Set 24 | beyneu
# Processing Record 32 of Set 24 | xining
# Processing Record 33 of Set 24 | saint-joseph
# Processing Record 34 of Set 24 | zakamensk
# Processing Record 35 of Set 24 | lure
# Processing Record 36 of Set 24 | urcos
# Processing Record 37 of Set 24 | kobryn
# Processing Record 38 of Set 24 | autazes
# Processing Record 39 of Set 24 | zaraza
# Processing Record 40 of Set 24 | cerrito
# Processing Record 41 of Set 24 | nurota
# Processing Record 42 of Set 24 | turbat
# Processing Record 43 of Set 24 | villarrica
# Processing Record 44 of Set 24 | shache
# Processing Record 45 of Set 24 | tianpeng
# Processing Record 46 of Set 24 | north myrtle beach
# Processing Record 47 of Set 24 | uyemskiy
# Processing Record 48 of Set 24 | urumqi
# Processing Record 49 of Set 24 | meghraj
# Processing Record 50 of Set 24 | tura
# Processing Record 1 of Set 25 | bulgan
# Processing Record 2 of Set 25 | cururupu
# Processing Record 3 of Set 25 | alofi
# Processing Record 4 of Set 25 | plettenberg bay
# Processing Record 5 of Set 25 | grenada
# Processing Record 6 of Set 25 | rehnan
# Processing Record 7 of Set 25 | hami
# Processing Record 8 of Set 25 | alliance
# Processing Record 9 of Set 25 | chiredzi
# Processing Record 10 of Set 25 | nautla
# Processing Record 11 of Set 25 | kaeo
# Processing Record 12 of Set 25 | okitipupa
# Processing Record 13 of Set 25 | inhambane
# Processing Record 14 of Set 25 | colon
# Processing Record 15 of Set 25 | blaubeuren
# Processing Record 16 of Set 25 | mpika
# Processing Record 17 of Set 25 | goianinha
# Processing Record 18 of Set 25 | trinidad
# Processing Record 19 of Set 25 | kavaratti
# Processing Record 20 of Set 25 | barcelos
# Processing Record 21 of Set 25 | warmbad
# Processing Record 22 of Set 25 | weru
# Processing Record 23 of Set 25 | parabel
# Processing Record 24 of Set 25 | poselki
# Processing Record 25 of Set 25 | coos bay
# Processing Record 26 of Set 25 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 25 | mendi
# Processing Record 28 of Set 25 | umea
# Processing Record 29 of Set 25 | taltal
# Processing Record 30 of Set 25 | bambanglipuro
# Processing Record 31 of Set 25 | kaa-khem
# Processing Record 32 of Set 25 | casino
# Processing Record 33 of Set 25 | qandala
# Processing Record 34 of Set 25 | solnechnyy
# Processing Record 35 of Set 25 | bagdarin
# Processing Record 36 of Set 25 | nioro
# Processing Record 37 of Set 25 | lillooet
# Processing Record 38 of Set 25 | mosalsk
# Processing Record 39 of Set 25 | monte gordo
# Processing Record 40 of Set 25 | moose factory
# Processing Record 41 of Set 25 | lensk
# Processing Record 42 of Set 25 | las vegas
# Processing Record 43 of Set 25 | san policarpo
# Processing Record 44 of Set 25 | koumac
# Processing Record 45 of Set 25 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 25 | dauphin
# Processing Record 47 of Set 25 | port lincoln
# Processing Record 48 of Set 25 | kabinda
# Processing Record 49 of Set 25 | ouadda
# Processing Record 50 of Set 25 | coahuayana
# Processing Record 1 of Set 26 | tara
# Processing Record 2 of Set 26 | russell
# Processing Record 3 of Set 26 | consett
# Processing Record 4 of Set 26 | saint-pierre
# Processing Record 5 of Set 26 | pangkalanbuun
# Processing Record 6 of Set 26 | abu samrah
# Processing Record 7 of Set 26 | liuzhou
# Processing Record 8 of Set 26 | kizhinga
# Processing Record 9 of Set 26 | el alto
# Processing Record 10 of Set 26 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 26 | camacha
# Processing Record 12 of Set 26 | horsham
# Processing Record 13 of Set 26 | kruisfontein
# Processing Record 14 of Set 26 | churapcha
# Processing Record 15 of Set 26 | baikunthpur
# Processing Record 16 of Set 26 | nosy varika
# Processing Record 17 of Set 26 | chilca
# Processing Record 18 of Set 26 | guaratuba
# Processing Record 19 of Set 26 | riyadh
# Processing Record 20 of Set 26 | ranong
# Processing Record 21 of Set 26 | fukue
# Processing Record 22 of Set 26 | ouallam
# Processing Record 23 of Set 26 | bulawayo
# Processing Record 24 of Set 26 | joensuu
# Processing Record 25 of Set 26 | inverness
# Processing Record 26 of Set 26 | limbang
# Processing Record 27 of Set 26 | rio grande
# Processing Record 28 of Set 26 | nome
# Processing Record 29 of Set 26 | kifri
# Processing Record 30 of Set 26 | wisconsin rapids
# Processing Record 31 of Set 26 | san juan de uraba
# Processing Record 32 of Set 26 | mackay
# Processing Record 33 of Set 26 | boa viagem
# Processing Record 34 of Set 26 | colorado springs
# Processing Record 35 of Set 26 | marevo
# Processing Record 36 of Set 26 | iracoubo
# Processing Record 37 of Set 26 | jibuti
# Processing Record 38 of Set 26 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 26 | almaty
# Processing Record 40 of Set 26 | comodoro rivadavia
# Processing Record 41 of Set 26 | poum
# Processing Record 42 of Set 26 | san andres
# Processing Record 43 of Set 26 | bekhtery
# Processing Record 44 of Set 26 | chifeng
# Processing Record 45 of Set 26 | tiarei
# Processing Record 46 of Set 26 | chontalpa
# Processing Record 47 of Set 26 | savannah bight
# Processing Record 48 of Set 26 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 26 | abomsa
# Processing Record 50 of Set 26 | college
# Processing Record 1 of Set 27 | angoche
# Processing Record 2 of Set 27 | mpulungu
# Processing Record 3 of Set 27 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 27 | porto santo
# Processing Record 5 of Set 27 | goundi
# Processing Record 6 of Set 27 | urucara
# Processing Record 7 of Set 27 | kirgiz-miyaki
# Processing Record 8 of Set 27 | feijo
# Processing Record 9 of Set 27 | muzaffarabad
# Processing Record 10 of Set 27 | chapada dos guimaraes
# Processing Record 11 of Set 27 | terney
# Processing Record 12 of Set 27 | bara
# Processing Record 13 of Set 27 | kaduqli
# Processing Record 14 of Set 27 | lazaro cardenas
# Processing Record 15 of Set 27 | jishou
# Processing Record 16 of Set 27 | havelock
# Processing Record 17 of Set 27 | canavieiras
# Processing Record 18 of Set 27 | xapuri
# Processing Record 19 of Set 27 | margate
# Processing Record 20 of Set 27 | swellendam
# Processing Record 21 of Set 27 | pangai
# Processing Record 22 of Set 27 | komsomolskiy
# Processing Record 23 of Set 27 | eureka
# Processing Record 24 of Set 27 | maridi
# Processing Record 25 of Set 27 | pinheiro machado
# Processing Record 26 of Set 27 | buin
# Processing Record 27 of Set 27 | oruro
# Processing Record 28 of Set 27 | timizart
# Processing Record 29 of Set 27 | temba
# Processing Record 30 of Set 27 | bud
# Processing Record 31 of Set 27 | vila franca do campo
# Processing Record 32 of Set 27 | urengoy
# Processing Record 33 of Set 27 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 27 | fram
# Processing Record 35 of Set 27 | rawson
# Processing Record 36 of Set 27 | dukhovshchina
# Processing Record 37 of Set 27 | paso de carrasco
# Processing Record 38 of Set 27 | ler
# Processing Record 39 of Set 27 | marfino
# Processing Record 40 of Set 27 | granja
# Processing Record 41 of Set 27 | payo
# Processing Record 42 of Set 27 | port angeles
# Processing Record 43 of Set 27 | ust-ishim
# Processing Record 44 of Set 27 | hegang
# Processing Record 45 of Set 27 | tabory
# Processing Record 46 of Set 27 | cayenne
# Processing Record 47 of Set 27 | colares
# Processing Record 48 of Set 27 | quang ngai
# Processing Record 49 of Set 27 | vanderhoof
# Processing Record 50 of Set 27 | am timan
# Processing Record 1 of Set 28 | worland
# Processing Record 2 of Set 28 | houma
# Processing Record 3 of Set 28 | novo aripuana
# Processing Record 4 of Set 28 | karpathos
# Processing Record 5 of Set 28 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 28 | merauke
# Processing Record 7 of Set 28 | ambilobe
# Processing Record 8 of Set 28 | pemba
# Processing Record 9 of Set 28 | itamaraca
# Processing Record 10 of Set 28 | tulun
# Processing Record 11 of Set 28 | algiers
# Processing Record 12 of Set 28 | krasnosilka
# Processing Record 13 of Set 28 | black river
# Processing Record 14 of Set 28 | barranca
# Processing Record 15 of Set 28 | udachnyy
# Processing Record 16 of Set 28 | yumen
# Processing Record 17 of Set 28 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 28 | yulara
# Processing Record 19 of Set 28 | san patricio
# Processing Record 20 of Set 28 | mountain home
# Processing Record 21 of Set 28 | sheridan
# Processing Record 22 of Set 28 | tromso
# Processing Record 23 of Set 28 | heide
# Processing Record 24 of Set 28 | beloha
# Processing Record 25 of Set 28 | laakirchen
# Processing Record 26 of Set 28 | bhag
# Processing Record 27 of Set 28 | wagar
# Processing Record 28 of Set 28 | tamandare
# Processing Record 29 of Set 28 | amapa
# Processing Record 30 of Set 28 | key west
# Processing Record 31 of Set 28 | chake chake
# Processing Record 32 of Set 28 | san juan
# Processing Record 33 of Set 28 | mogadishu
# Processing Record 34 of Set 28 | vigrestad
# Processing Record 35 of Set 28 | nizwa
# Processing Record 36 of Set 28 | banda aceh
# Processing Record 37 of Set 28 | yunhe
# Processing Record 38 of Set 28 | poya
# Processing Record 39 of Set 28 | olga
# Processing Record 40 of Set 28 | olafsvik
# Processing Record 41 of Set 28 | san luis
# Processing Record 42 of Set 28 | balikpapan
# Processing Record 43 of Set 28 | radchenko
# Processing Record 44 of Set 28 | eyl
# Processing Record 45 of Set 28 | shiraz
# Processing Record 46 of Set 28 | zhangjiakou
# Processing Record 47 of Set 28 | san quintin
# Processing Record 48 of Set 28 | bauchi
# Processing Record 49 of Set 28 | maneadero
# Processing Record 50 of Set 28 | namatanai
# Processing Record 1 of Set 29 | shubarshi
# Processing Record 2 of Set 29 | catalina
# Processing Record 3 of Set 29 | ayagoz
# Processing Record 4 of Set 29 | verkh-usugli
# Processing Record 5 of Set 29 | buribay
# Processing Record 6 of Set 29 | virginia beach
# Processing Record 7 of Set 29 | ust-maya
# Processing Record 8 of Set 29 | belaya gora
# Processing Record 9 of Set 29 | mtwara
# Processing Record 10 of Set 29 | carutapera
# Processing Record 11 of Set 29 | ho
# City not found. Skipping...
# Processing Record 12 of Set 29 | marquette
# Processing Record 13 of Set 29 | alghero
# Processing Record 14 of Set 29 | astoria
# Processing Record 15 of Set 29 | plyussa
# Processing Record 16 of Set 29 | tsabong
# Processing Record 17 of Set 29 | den helder
# Processing Record 18 of Set 29 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 29 | kargasok
# Processing Record 20 of Set 29 | ihosy
# Processing Record 21 of Set 29 | usinsk
# Processing Record 22 of Set 29 | yomou
# Processing Record 23 of Set 29 | nihtaur
# Processing Record 24 of Set 29 | moussoro
# Processing Record 25 of Set 29 | pitkyaranta
# Processing Record 26 of Set 29 | kokologo
# Processing Record 27 of Set 29 | ucluelet
# Processing Record 28 of Set 29 | agadez
# Processing Record 29 of Set 29 | a
# City not found. Skipping...
# Processing Record 30 of Set 29 | yeniseysk
# Processing Record 31 of Set 29 | cherskiy
# Processing Record 32 of Set 29 | rexburg
# Processing Record 33 of Set 29 | anantapur
# Processing Record 34 of Set 29 | dianopolis
# City not found. Skipping...
# Processing Record 35 of Set 29 | batemans bay
# Processing Record 36 of Set 29 | manado
# Processing Record 37 of Set 29 | san
# Processing Record 38 of Set 29 | gouyave
# Processing Record 39 of Set 29 | kachiry
# Processing Record 40 of Set 29 | ksenyevka
# City not found. Skipping...
# Processing Record 41 of Set 29 | egvekinot
# Processing Record 42 of Set 29 | santa isabel
# Processing Record 43 of Set 29 | iacu
# Processing Record 44 of Set 29 | puerto ayacucho
# Processing Record 45 of Set 29 | catuday
# Processing Record 46 of Set 29 | vesoul
# Processing Record 47 of Set 29 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 29 | dire
# Processing Record 49 of Set 29 | rio de janeiro
# Processing Record 50 of Set 29 | westpunt
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Burla  21.5000   83.8667     73.47        31           0
# 1  Arraial Do Cabo -22.9661  -42.0278     89.56        61           0
# 2          Dunedin -45.8742  170.5036     63.81        91          98
# 3            Mezen  65.8522   44.2400      3.52        97         100
# 4         Kommunar  59.6206   30.3900     22.53        94          92
# 5        Busselton -33.6500  115.3333     68.04        67          14
# 6          Kahului  20.8947 -156.4700     65.46        88          20
# 7        Jiayuguan  39.8167   98.3000     40.91        33          85
# 8          Inirida   3.8653  -67.9239     82.40        71         100
# 9           Kodiak  57.7900 -152.4072     36.91        87         100
#
#    Wind Speed Country Current Description
# 0        3.18      IN           clear sky
# 1       13.80      BR           clear sky
# 2        3.83      NZ     overcast clouds
# 3        4.45      RU     overcast clouds
# 4        5.41      RU     overcast clouds
# 5       12.08      AU          few clouds
# 6        3.44      US          few clouds
# 7       21.72      CN     overcast clouds
# 8        3.85      CO     overcast clouds
# 9        8.05      US     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Burla      IN  21.5000   83.8667     73.47        31
# 1    Arraial Do Cabo      BR -22.9661  -42.0278     89.56        61
# 2            Dunedin      NZ -45.8742  170.5036     63.81        91
# 3              Mezen      RU  65.8522   44.2400      3.52        97
# 4           Kommunar      RU  59.6206   30.3900     22.53        94
# ..               ...     ...      ...       ...       ...       ...
# 689  Puerto Ayacucho      VE   5.6639  -67.6236     91.18        43
# 690          Catuday      PH  16.2923  119.8062     77.47        75
# 691           Vesoul      FR  47.5833    5.8333     44.83        58
# 692             Dire      ML  12.2833  -10.9667     98.06        12
# 693   Rio De Janeiro      BR -22.9028  -43.2075     93.15        57
#
#      Cloudiness  Wind Speed Current Description
# 0             0        3.18           clear sky
# 1             0       13.80           clear sky
# 2            98        3.83     overcast clouds
# 3           100        4.45     overcast clouds
# 4            92        5.41     overcast clouds
# ..          ...         ...                 ...
# 689          92        3.85     overcast clouds
# 690          95        6.02     overcast clouds
# 691           1        4.41           clear sky
# 692           1        5.93           clear sky
# 693          20       13.80          few clouds
#
# [694 rows x 9 columns]

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv", index=False)
